# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitstar01/2048-ai/blob/master/english_maze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd
import re
import numpy as np
import pyautogui
import time
import math
import random


# In[2]:


data=pd.read_csv("word-meaning-examples.csv")
data.head()


# In[3]:


def parser1(text,x,y,s):
    text=text.lower()
    if s==text[0]:
        for a in text:
            if a==" " or a=="-" or a==x or a==y:
                return np.nan
        return text
    return np.nan
    


# In[4]:


def parser1(text,x,y,s):
    text=text.lower()
    if s==text[0]:
        for a in text:
            if a==" " or a=="-" or a==x or a==y:
                return np.nan
        return text
    return np.nan
    
def findw(one,two,start):
    x=data['Word'].apply(lambda x:parser1(x,one,two,start))
    x.dropna(inplace=True)
    l=0
    s=""
    for w in x:
        if l<len(w):
            l=len(w)
            s=w
    return s


# In[ ]:





# In[36]:


import pyautogui as pyt
import time
while True:
    print(pyt.position())
    time.sleep(1)


# In[38]:


import matplotlib.pyplot as plt
for i in range(1,10):
    print(plt.imshow(pyt.screenshot(region=(52+i*44,822, 38,38))))    


# In[42]:


for i in range(1,9):
    print(plt.imshow(pyt.screenshot(region=(52+i*44+1*23,822+1*66, 38,38))))
    


# In[43]:


for i in range(1,7):
    print(plt.imshow(pyt.screenshot(region=(52+i*44+1*23,822+1*66, 38,38))))
    


# In[66]:


for i in range(10):
    x,y=pyautogui.position()
    color=pyautogui.pixel(x,y)
    print(x,y,color)
    time.sleep(1)


# In[281]:


alpha=['q','w','e','r','t','y','u','i','o','p','a','s','d','f','g','h','j','k','l','z','x','c','v','b','n','m']
d={i:alpha[i] for i in range(26)}
di={alpha[i]:i for i in range(26)}


# In[118]:


alpha=['q','w','e','r','t','y','u','i','o','p','a','s','d','f','g','h','j','k','l','z','x','c','v','b','n','m']
d={i:alpha[i] for i in range(26)}
di={alpha[i]:i for i in range(26)}

def checkcolor(t):
    if(t[2]>120 and t[2]<126):
        return 1
    elif(t[2]>0 and t[2]<5):
        return 2
    else:
        return 0
x=80
y=865
dx=46
dy=67
dxy=22
j=0
g=[]
r=[]
for i in range(10):
#     pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    t=pyautogui.pixel(x+i*dx+dxy*j,y+dy*j)
    if(checkcolor(t)==1):
        g.append(d[i])
    elif(checkcolor(t)==2):
        r.append(d[i])
        
j=1
for i in range(9):
#     pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    t=pyautogui.pixel(x+i*dx+dxy*j,y+dy*j)
    if(checkcolor(t)==1):
        g.append(d[i+10])
    elif(checkcolor(t)==2):
        r.append(d[i+10])
j=2
for i in range(7):
#     pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    t=pyautogui.pixel(x+i*dx+dxy*j,y+dy*j)
    if(checkcolor(t)==1):
        g.append(d[i+19])
    elif(checkcolor(t)==2):
        r.append(d[i+19])
if len(g)==0:
    g.append('a')
print(r,g)
w=findw(r[0],r[1],g[0])
print(w)
clickw(w)
time.sleep(3)
def clicker(i):
    if i>18:
        j=2
        i=i%19
        pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    elif i>9 :
        j=1
        i=i%10
        pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    else:
        j=0
        pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
def clickw(w):
    for i in range(len(w)):
        time.sleep(.01)
        clicker(di[w[i]])
clickw("manish")


# In[111]:


def clicker(i):
    if i>18:
        j=2
        i=i%19
        pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    elif i>9 :
        j=1
        i=i%10
        pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
    else:
        j=0
        pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)
def clickw(w):
    for i in range(len(w)):
        time.sleep(.01)
        clicker(di[w[i]])
clickw("manish")


# In[102]:


i=di['n']
i=i%19
j=2
pyautogui.moveTo(x+i*dx+dxy*j,y+dy*j)


# In[18]:


random.randint(0,25)


# In[73]:


tb=[]
x=[]
for i in range(10):
    x=[]
    for j in range(10):
        x.append(alpha[random.randint(0,25)])
    tb.append(x)
tb


# In[122]:


def fword(i,j,i1,j1):
    w1=''
#     print(i,j)
    if i!=i1 and j1!=j:
        if i<i1 and j<j1:
            while(i<i1 and j<j1):
                w1=w1+tb[i1][j1]
                j1=j1-1
                i1=i1-1
        elif i>i1 and j<j1:
            while(i>i1 and j<j1):
                w1=w1+tb[i1][j1]
                j1=j1-1
                i1=i1+1
        elif i<i1 and j>j1:
            while(i<i1 and j>j1):
                w1=w1+tb[i1][j1]
                j1=j1+1
                i1=i1-1
        elif i>i1 and j>j1:
            while(i>i1 and j>j1):
                w1=w1+tb[i1][j1]
                j1=j1+1
                i1=i1+1
    elif i==i1:
        if j<j1:
            while(j<j1):
                w1=w1+tb[i1][j1]
                j1=j1-1
        elif j>j1:
            while(j>j1):
                w1=w1+tb[i1][j1]
                j1=j1+1
    else :
        if i<i1:
            while(i<i1):
                w1=w1+tb[i1][j1]
                i1=i1-1
        elif i>i1:
            while(i>i1):
                w1=w1+tb[i1][j1]
                i1=i1+1
    return w1
            
def check(i,j,w):
    l=len(w)
    i1=i
    j1=j
    f=0
    if l>0:
        w1=fword(i,j,i1,j1)
        if(i-l)>0:
            w1=fword(i-l,j,i1,j1)
            if w==w1:
                f=1
        if(j-l)>0:
            w1=fword(i,j-l,i1,j1)
            if w==w1:
                f=1
        if(i-l)>0 and j-l>0:
            w1=fword(i-l,j-l,i1,j1)
            if w==w1:
                f=1
        if(i+l)<10 and j-l>0:
            w1=fword(i+l,j-l,i1,j1)
            if w==w1:
                f=1
        if(i-l)>0 and j+l<10:
            w1=fword(i-l,j+l,i1,j1)
            if w==w1:
                f=1
        if(i+l)<10:
            w1=fword(i+l,j,i1,j1)
            if w==w1:
                f=1
        if(j+l)<10:
            w1=fword(i,j+l,i1,j1)
            if w==w1:
                f=1
        if(i+l)<10 and j+l<10:
            w1=fword(i+l,j+l,i1,j1)
            if w==w1:
                f=1
    if(f==1):
        return True
    else:
        return False
def finder(w):
    for i in range(10):
        for j in range(10):
            if check(i,j,w):
                print(i,j)
            


# In[126]:


finder('moyr')


# In[121]:


check(9,5,'phq')


# In[105]:


l=-9
l=-l
7-l


# ## l=-9
# l=-l
# 7-l

# In[27]:


import pytesseract
import cv2
import matplotlib.pyplot as plt
from PIL import ImageGrab
import numpy as np
import cv2
img=cv2.imread('./test.PNG')
text=pytesseract.image_to_string(img)
print(text)


# In[21]:


try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

# If you don't have tesseract executable in your PATH, include the following:
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
# Example tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'

# Simple image to string
print(pytesseract.image_to_string(Image.open('test.PNG')))


# In[77]:


img = ImageGrab.grab(bbox=(180,857,240,877)) #bbox specifies specific region (bbox= x,y,width,height *starts top-left)
img=np.array(img)
_,im=cv.threshold(img,180,255,cv.THRESH_BINARY)
plt.imshow(im)


# In[50]:


import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('imgtext.png',0)
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,            cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,            cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()


# In[52]:


img = cv.imread('imgtext.png')
plt.imshow(img)


# In[6]:


import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('imgtext.png',0)
# global thresholding
ret1,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv.threshold(img,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv.GaussianBlur(img,(5,5),0)
ret3,th3 = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()


# In[12]:


import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('imgtext.png',0)
ret,thresh1 = cv.threshold(img,180,255,cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()


# In[130]:


from mss import mss
def toText(img):
    img_np = np.array(img) #this is the array obtained from conversion
    img = cv.cvtColor(img_np, cv.COLOR_BGR2GRAY)
    ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
    img=thresh1
#     img=cv.bitwise_not(thresh1)
    plt.imshow(img,'gray')
    tmp.append(pytesseract.image_to_string(img))
    print(pytesseract.image_to_string(img))


# In[184]:


def takeshot(t):
#     print(t[0],t[1])
    mon = {'top': t[1], 'left': t[0], 'width': 440, 'height': 50}
    sct = mss()
    img=sct.grab(mon)
#     plt.imshow(img)
    toText(img)
x=55
y=835
w=105
h=30
h1=10
query=[]
line=[]


# t1=time.time()
# for i in range(3):
#     line=[]
#     for j in range(4):
#         word=takeshot([x+w*j,y+(h+h1)*i])
#         line.append(word)
#     query.append(line)
# print(time.time()-t1)
# print(query)
tmp=[]
takeshot([30,360]) #print(takeshot([30,340]))


# In[182]:


tmp=[]
takeshot([30,323]) #print(takeshot([30,340]))


# In[155]:


import cv2
import numpy as np

img = cv2.imread('abcd.jpg')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

image = cv2.imread('abcd.jpg')

gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
print(pytesseract.image_to_string(cv2.bitwise_not(opening)))


# In[50]:


import os
import cv2
def takeshot1(t,k):
    print(t[0],t[1])
    mon = {'top': t[1], 'left': t[0], 'width': 36, 'height': 38}
    sct = mss()
    img=sct.grab(mon)
    img_np = np.array(img) #this is the array obtained from conversion
    img = cv2.cvtColor(img_np, cv2.COLOR_BGR2GRAY)
    ret,thresh1 = cv.threshold(img,170,255,cv.THRESH_BINARY)
#     img1=cv.bitwise_not(thresh1)
    plt.imshow(thresh1,'gray')
    for w in alpha:
        template = cv2.imread('./{}.jpg'.format(w),0)
        plt.imshow(template)
        print(w)
        detect(thresh1,template)
    cv.imwrite('{}.jpg'.format(k),thresh1)
    print(pytesseract.image_to_string(thresh1))
k=0
for i in range(10):
    for j in range(10):
        takeshot1([55+j*42,323+43*i],k)
        k=k+1


# In[338]:


def detect(img_gray,template):

    # Store width and height of template in w and h 
    w, h = template.shape[::-1] 

    # Perform match operations. 
    res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED) 

    # Specify a threshold 
    threshold = 0.1

    # Store the coordinates of matched area in a numpy array 
    loc = np.where( res >= threshold)  
    print(loc)
    # Draw a rectangle around the matched region. 
    for pt in zip(*loc[::-1]): 
        cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2) 

    # Show the final image with the matched area. 
    cv2.imshow('Detected',img_rgb) 


# In[340]:


img_rgb = cv2.imread('./43.jpg')
  
# Convert it to grayscale 
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
tmp = cv2.imread('./a.jpg',0)


detect(img_gray,tmp)


# In[335]:


tmp.shape


# In[322]:


cv2.imread('./z/')


# In[323]:


get_ipython().system('ls')


# In[ ]:
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-135a895d6c1a> in <module>()
#       8 import re
#       9 import numpy as np
# ---> 10 import pyautogui
#      11 import time
#      12 import math
#
# ModuleNotFoundError: No module named 'pyautogui'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
